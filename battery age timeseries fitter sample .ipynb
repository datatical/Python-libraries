# %%
import numpy as np
import pandas as pd
import seaborn as sns
from fitter import Fitter, get_common_distributions
# Now you can use get_common_distributions
distributions = get_common_distributions()
print(distributions)
# Out:
# ['cauchy', 'chi2', 'expon', 'exponpow', 'gamma', 'lognorm', 'norm', 'powerlaw', 'rayleigh', 'uniform']

# %%
dataset = pd.read_csv("age_timeseries.csv")
dataset.head()
# Out:
#    Charge Capacity (Ah)  Charge Energy (Wh)  \
# 0              0.000000            0.000000
# 1              2.484248            9.407449
# 2              2.477933            9.304501
# 3              2.651213            9.999107
# 4              2.225248            8.589358
#
#    Relaxation Potential - Charge (V)  Constant Voltage Charge Capacity (Ah)  \
# 0                                NaN                                    NaN
# 1                           4.199207                               0.098705
# 2                           4.199664                               0.006089
# 3                           4.199741                               0.051419
# 4                           4.199817                               0.221205
#
#    Constant Voltage Charge Energy (Wh)  Coulombic Efficiency  \
# 0                                  NaN                   NaN
# 1                             0.414558              0.987611
# ...

# %%
dataset.info
# Out:
# <bound method DataFrame.info of      Charge Capacity (Ah)  Charge Energy (Wh)  \
# 0                0.000000            0.000000
# 1                2.484248            9.407449
# 2                2.477933            9.304501
# 3                2.651213            9.999107
# 4                2.225248            8.589358
# ..                    ...                 ...
# 447              1.176411            4.739985
# 448              1.162926            4.689341
# 449              1.156187            4.664577
# 450              1.148024            4.632955
# 451              1.121800            4.526721
#
#      Relaxation Potential - Charge (V)  Constant Voltage Charge Capacity (Ah)  \
# 0                                  NaN                                    NaN
# 1                             4.199207                               0.098705
# 2                             4.199664                               0.006089
# ...

# %%
sns.set_style('dark')
sns.set_context("paper", font_scale = 2)
sns.displot(data=dataset, x="Constant Voltage Charge Energy (Wh)", kind="hist", bins = 100, aspect = 1.5)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Check the column names in your dataset DataFrame
print(dataset.columns)

# Specify the correct column name for the x parameter
sns.displot(data=dataset, x="Total Charge Time (s)", kind="hist", bins=100, aspect=1.5)
# Out:
# Index(['Charge Capacity (Ah)', 'Charge Energy (Wh)',
#        'Relaxation Potential - Charge (V)',
#        'Constant Voltage Charge Capacity (Ah)',
#        'Constant Voltage Charge Energy (Wh)', 'Coulombic Efficiency',
#        'Cumulative Charge Capacity (Ah)', 'Cumulative Charge Energy (Wh)',
#        'Cumulative Discharge Capacity (Ah)',
#        'Cumulative Discharge Energy (Wh)', 'Constant Voltage Charge Time (s)',
#        'Constant Voltage Discharge Time (s)', 'Cycle Number',
#        'Discharge Capacity (Ah)', 'Discharge Energy (Wh)',
#        'Relaxation Potential - Discharge (V)', 'Cycle End Timestamp',
#        'Cycle End Time (s)', 'Energy Efficiency', 'Final Charge Potential (V)',
#        'Final Discharge Potential (V)', 'Initial Charge Potential (V)',
#        'Initial Discharge Potential (V)',
#        'Internal Resistance End of Charge (Ω)',
#        'Internal Resistance End of Discharge (Ω)',
#        'Internal Resistance Start of Charge (Ω)',
# ...

# %%
 height = dataset["Cycle Start Time (s)"].values

# %%
f = Fitter(height,
           distributions=['gamma',
                          'lognorm',
                          "beta",
                          "burr",
                          "norm"])
f.fit()
f.summary()
# Out:
#          sumsquare_error          aic          bic  kl_div  ks_statistic  \
# beta        7.528822e-13  3123.262163  3139.716892     inf      0.041546
# gamma       1.034423e-12  3155.856046  3168.197092     inf      0.072625
# norm        1.034630e-12  3153.847266  3162.074630     inf      0.073151
# lognorm     4.663690e-12  3679.604475  3691.945522     inf      0.808710
# burr        4.736944e-12  3634.331124  3650.785853     inf      0.632845
#
#              ks_pvalue
# beta      4.052374e-01
# gamma     1.613672e-02
# norm      1.504896e-02
# lognorm  2.440684e-321
# burr     5.254105e-176

# %%
f.get_best(method = 'sumsquare_error')
# Out:
# {'beta': {'a': 1.1628669117397712,
#   'b': 1.0555849582792232,
#   'loc': -4716.789813267973,
#   'scale': 5779114.423090042}}

# %%
#identifying the parameters
f.fitted_param["beta"]
# Out:
# (1.1628669117397712, 1.0555849582792232, -4716.789813267973, 5779114.423090042)

# %%
#Fitting Distributions on a Randomly Drawn Data
#Common distributions --the Fitter library also has a get_common_distribution( ) method
get_common_distributions()
# Out:
# ['cauchy',
#  'chi2',
#  'expon',
#  'exponpow',
#  'gamma',
#  'lognorm',
#  'norm',
#  'powerlaw',
#  'rayleigh',
#  'uniform']

# %%
#Generating data from the normal distribution
mu, sigma = 0, 0.1 # mean and standard deviation
data = np.random.normal(mu, sigma, 10000)
data
# Out:
# array([-0.18640133, -0.0319481 , -0.008372  , ...,  0.09366436,
#        -0.02655173, -0.10088221])

# %%
# the sumsquared_error criteria the best-fitted distribution is the normal distribution
f = Fitter(data,
           distributions= get_common_distributions())
f.fit()
f.summary()
# Out:
#           sumsquare_error         aic         bic  kl_div  ks_statistic  \
# norm             1.091920  270.285236  284.705916     inf      0.005967
# gamma            1.103256  270.681297  292.312318     inf      0.006090
# lognorm          1.110956  270.457465  292.088486     inf      0.006316
# exponpow        17.405548  651.619639  673.250660     inf      0.059735
# cauchy          26.453930  120.121946  134.542626     inf      0.075049
#
#              ks_pvalue
# norm      8.664588e-01
# gamma     8.499027e-01
# lognorm   8.174110e-01
# exponpow  1.846647e-31
# cauchy    1.982833e-49

# %%
#Get best-fitted distribution and parameters
f.get_best(method = 'sumsquare_error')
# Out:
# {'norm': {'loc': -0.0006919887923872659, 'scale': 0.10093312420129114}}

# %%
#Get all supported distributions
from fitter import Fitter, get_common_distributions

# Get a list of common distributions
distributions = get_common_distributions()
print(distributions)
# Out:
# ['cauchy', 'chi2', 'expon', 'exponpow', 'gamma', 'lognorm', 'norm', 'powerlaw', 'rayleigh', 'uniform']

# %%
height1 = dataset["Cumulative Discharge Energy (Wh)"].values

# %%
f = Fitter(height1,
           distributions=['gamma',
                          'lognorm',
                          "beta",
                          "burr",
                          "norm"])
f.fit()
f.summary()
# Out:
#          sumsquare_error          aic          bic    kl_div  ks_statistic  \
# beta        2.713605e-07  1647.708754  1664.163482  0.012244      0.061038
# burr        3.754883e-07  1629.777403  1646.232132  0.016171      0.040713
# norm        1.926825e-06  1659.706313  1667.933677  0.109806      0.075168
# gamma       1.936431e-06  1661.659139  1674.000186  0.110101      0.076576
# lognorm     1.794054e-05  2138.692101  2151.033148  1.902772      0.785895
#
#              ks_pvalue
# beta      6.609259e-02
# burr      4.306136e-01
# norm      1.146217e-02
# gamma     9.435492e-03
# lognorm  2.432205e-297

# %%
f.get_best(method = 'sumsquare_error')
# Out:
# {'beta': {'a': 1.0453712494491811,
#   'b': 0.7542226593582193,
#   'loc': -322.77391241842065,
#   'scale': 3592.7382491889207}}

# %%
#Fitting Distributions on a Randomly Drawn Data
#Common distributions --the Fitter library also has a get_common_distribution( ) method
get_common_distributions()
# Out:
# ['cauchy',
#  'chi2',
#  'expon',
#  'exponpow',
#  'gamma',
#  'lognorm',
#  'norm',
#  'powerlaw',
#  'rayleigh',
#  'uniform']

# %%
# the sumsquared_error criteria the best-fitted distribution is the normal distribution
f = Fitter(data,
           distributions= get_common_distributions())
f.fit()
f.summary()
# Out:
#           sumsquare_error         aic         bic  kl_div  ks_statistic  \
# norm             1.091920  270.285236  284.705916     inf      0.005967
# gamma            1.103256  270.681297  292.312318     inf      0.006090
# lognorm          1.110956  270.457465  292.088486     inf      0.006316
# exponpow        17.405548  651.619639  673.250660     inf      0.059735
# cauchy          26.453930  120.121946  134.542626     inf      0.075049
#
#              ks_pvalue
# norm      8.664588e-01
# gamma     8.499027e-01
# lognorm   8.174110e-01
# exponpow  1.846647e-31
# cauchy    1.982833e-49
